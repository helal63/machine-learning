# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os
import sys

# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

x = layers.Dropout(0.4)(x)

x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

discriminator_optimizer = keras.optimizers.RMSprop(
    lr=0.0008,
    clipvalue=1.0,
    decay=1e-8)

discriminator.compile(optimizer=discriminator_optimizer,
                      loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
import os
from keras.preprocessing import image

(x_train, y_train), (_, _)= keras.datasets.cifar10.load_data()

x_train = x_train[y_train.flatten() == 6]

x_train = x_train.reshape(
    (x_train.shape[0],) +
    (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = '/home/john/ml/GAN'

start = 0
for step in range(iterations):
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
    
    generated_images = generator.predict(random_latent_vectors)
    
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])
    
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    labels += 0.05 * np.random.random(labels.shape)
    
    d_loss = discriminator.train_on_batch(combined_images, labels)
    
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
    
    misleading_targets = np.zeros((batch_size, 1))
    
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
        start = 0
    
    if step % 100 == 0:
        gan.save_weights('gan.h5')
        
        print('discriminator loss:', d_loss)
        print('adversarial loss:', a_loss)
        
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))
        
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# /home/john/.local/lib/python3.6/site-packages/keras/engine/training.py:479: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# discriminator loss: 0.6025895
# adversarial loss: 1.1193299
# discriminator loss: 0.70076466
# adversarial loss: 0.8139246
# discriminator loss: 0.6962148
# adversarial loss: 0.75637305
# discriminator loss: 0.6931806
# adversarial loss: 0.749864
# discriminator loss: 0.7028904
# adversarial loss: 0.7609371
# discriminator loss: 0.7060212
# adversarial loss: 0.72593534
# discriminator loss: 0.7303379
# adversarial loss: 1.1461388
# discriminator loss: 0.6886064
# adversarial loss: 0.81632864
# discriminator loss: 0.8570382
# adversarial loss: 0.7519517
# discriminator loss: 0.70074326
# adversarial loss: 0.76067877
# discriminator loss: 0.68939567
# adversarial loss: 0.73264205
# discriminator loss: 0.70651287
# adversarial loss: 0.86869717
# discriminator loss: 0.6864368
# adversarial loss: 0.89637136
# discriminator loss: 0.6934002
# adversarial loss: 0.7775479
# discriminator loss: 0.6900697
# adversarial loss: 0.7391081
# discriminator loss: 0.69568807
# adversarial loss: 0.7290917
# discriminator loss: 0.7520196
# adversarial loss: 0.7476958
# discriminator loss: 0.7033106
# adversarial loss: 0.73443574
# discriminator loss: 0.6882417
# adversarial loss: 0.7600787
# discriminator loss: 0.70140177
# adversarial loss: 0.7637039
# discriminator loss: 0.6893988
# adversarial loss: 0.7914871
# discriminator loss: 0.6939236
# adversarial loss: 0.7314921
# discriminator loss: 0.68855554
# adversarial loss: 0.76525867
# discriminator loss: 0.69004464
# adversarial loss: 0.75237477
# discriminator loss: 0.69196594
# adversarial loss: 0.76321113
# discriminator loss: 0.6929655
# adversarial loss: 0.7964325
# discriminator loss: 0.7061774
# adversarial loss: 0.7246793
# discriminator loss: 0.7060902
# adversarial loss: 0.7594897
# discriminator loss: 0.7172369
# adversarial loss: 0.72264755
# discriminator loss: 0.701566
# adversarial loss: 0.7854735
# discriminator loss: 0.6927241
# adversarial loss: 0.7436492
# discriminator loss: 0.69716674
# adversarial loss: 0.753852
# discriminator loss: 0.69688505
# adversarial loss: 0.7821826
# discriminator loss: 0.70573837
# adversarial loss: 0.7453626
# discriminator loss: 0.7025692
# adversarial loss: 0.75503606
# discriminator loss: 0.68779516
# adversarial loss: 0.73815554
# discriminator loss: 0.68942964
# adversarial loss: 0.7381786
# discriminator loss: 0.6943718
# adversarial loss: 0.7516537
# discriminator loss: 0.6854063
# adversarial loss: 0.74277467
# discriminator loss: 0.7164219
# adversarial loss: 0.7418758
# discriminator loss: 0.6882385
# adversarial loss: 0.7300433
# discriminator loss: 0.70589125
# adversarial loss: 0.7497488
# discriminator loss: 0.6965264
# adversarial loss: 0.7533481
# discriminator loss: 0.7694545
# adversarial loss: 0.86373985
# discriminator loss: 0.6880584
# adversarial loss: 0.7359346
# discriminator loss: 0.7073539
# adversarial loss: 0.7249334
# discriminator loss: 1.3011026
# adversarial loss: 0.78218114
# discriminator loss: 0.68428725
# adversarial loss: 0.801099
# discriminator loss: 0.7092765
# adversarial loss: 0.79023457
# discriminator loss: 0.6929516
# adversarial loss: 0.7543915
# discriminator loss: 0.6967219
# adversarial loss: 0.6761155
# discriminator loss: 0.68651235
# adversarial loss: 0.77395034
# discriminator loss: 0.69872165
# adversarial loss: 0.8336048
# discriminator loss: 0.69548213
# adversarial loss: 0.9386589
# discriminator loss: 0.6972646
# adversarial loss: 0.8034338
# discriminator loss: 0.7009204
# adversarial loss: 0.75423884
# discriminator loss: 0.69385165
# adversarial loss: 0.75887436
# discriminator loss: 0.67983234
# adversarial loss: 0.8779694
# discriminator loss: 0.70568824
# adversarial loss: 0.84603244
# discriminator loss: 0.72379506
# adversarial loss: 0.6886973
# discriminator loss: 0.69974154
# adversarial loss: 0.7547291
# discriminator loss: 0.68874824
# adversarial loss: 0.7627646
# discriminator loss: 0.741686
# adversarial loss: 0.99591523
# discriminator loss: 0.70809567
# adversarial loss: 0.8176955
# discriminator loss: 0.6860328
# adversarial loss: 0.75356615
# discriminator loss: 0.6967342
# adversarial loss: 0.7848212
# discriminator loss: 0.6820658
# adversarial loss: 0.59831345
# discriminator loss: 0.6891306
# adversarial loss: 0.7166516
# discriminator loss: 0.6868862
# adversarial loss: 0.67373437
# discriminator loss: 0.7038089
# adversarial loss: 0.74447477
# discriminator loss: 0.66684484
# adversarial loss: 0.7341486
# discriminator loss: 0.67206407
# adversarial loss: 0.7192662
# discriminator loss: 0.7130985
# adversarial loss: 0.84512866
# discriminator loss: 0.7829449
# adversarial loss: 1.0984088
# discriminator loss: 0.6911327
# adversarial loss: 0.7505409
# discriminator loss: 0.7181612
# adversarial loss: 0.9464401
# discriminator loss: 0.6911542
# adversarial loss: 0.79582244
# discriminator loss: 0.73363316
# adversarial loss: 0.8041199
# discriminator loss: 0.6976932
# adversarial loss: 0.8468959
# discriminator loss: 0.66825384
# adversarial loss: 0.776437
# discriminator loss: 0.6939581
# adversarial loss: 0.92467594
# discriminator loss: 0.6605288
# adversarial loss: 0.73890764
# discriminator loss: 0.66177666
# adversarial loss: 0.89419395
# discriminator loss: 0.6617124
# adversarial loss: 1.0819495
# discriminator loss: 0.7032486
# adversarial loss: 0.98054266
# discriminator loss: 0.6917545
# adversarial loss: 0.9080812
# discriminator loss: 0.684965
# adversarial loss: 0.79325026
# discriminator loss: 0.7488862
# adversarial loss: 0.9309128
# discriminator loss: 0.6907994
# adversarial loss: 0.7652219
# discriminator loss: 0.7006705
# adversarial loss: 0.78603095
# discriminator loss: 0.7148295
# adversarial loss: 0.5823988
# discriminator loss: 0.68377066
# adversarial loss: 0.730497
# discriminator loss: 0.7028322
# adversarial loss: 1.013171
# discriminator loss: 0.6828371
# adversarial loss: 1.0007515
# discriminator loss: 0.72240126
# adversarial loss: 0.71194917
# discriminator loss: 0.6616289
# adversarial loss: 0.82999384
# discriminator loss: 0.7032064
# adversarial loss: 0.78254074
# discriminator loss: 0.7054078
# adversarial loss: 0.7962072
# discriminator loss: 0.7404305
# adversarial loss: 0.7523187
# discriminator loss: 0.7284943
# adversarial loss: 0.7209564
