# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Using TensorFlow backend.
# Corpus length: 600893

# %%
maxlen = 60

step = 3

sentences = []

next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=64, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed "' + generated_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
                
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 339s 2ms/step - loss: 1.9561
# --- Generating with seed "k, the feeling of separation from the multitude with
# their d"
# ------ temperature: 0.2
# k, the feeling of separation from the multitude with
# their decession of the present and desire and the sense the work of the interpore of the strust of the be in the every even the work of the interpored of the sense the strust of the sense the work to the most man the sense the precise of the most the sense the fart of the more the will the precise to the work of the believes of the work of the intiment of the same in the the strust of the strust and inte------ temperature: 0.5
# ntiment of the same in the the strust of the strust and interine in the longer of the inderention in the strusg and interpority and every exce to same is a musito the good man is a manitades of the does that which i preace, the real to means and dection man in the what the lawed that with the soul not even the intypering and lawed and self-ford, and intimed and ender in the
# interstions and laight in the may in tere, the desire of the spirits in the
# intimen------ temperature: 1.0
# in the may in tere, the desire of the spirits in the
# intiment noar and in the bathought of eduis to to dekelf prinoth of a mistids
# powerfoct impalth, as teat paride to the leavis. and
# gard wagher. in the groolemon medagely doop is -        tend y
# will ope ord valummanennems when whith to man fort geneuule, and there in re" "-the ficise is stillity, and to continulr, is coulder what all exole the orrlation, ingening to itself--theve the spantikene to
# rexult------ temperature: 1.2
# rrlation, ingening to itself--theve the spantikene to
# rexulting
# -digntingx unimststrustedhtrustorarting edkm. mean waek! en a valu. therefarthron prase wi nature,ournh. wh, i
# in man.--uptixe alm is itses ectivetsi: our jost abmices mush
# cruencully agained evence
# possy. ay as
# other consirer-dnlye at thie priecture, enough, the greriac
# "dobghous of were eredect med fines in istnecond.
# g3(errer accord as will semflre owes."--         he inlice one gidn:. by bepoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 342s 2ms/step - loss: 1.6407
# --- Generating with seed "icial interpretation
# of every word he utters, every step he "
# ------ temperature: 0.2
# icial interpretation
# of every word he utters, every step he self-delight of the spirit and the the still and the sense the self-perceives the the spirit the super to the sense the self-presention of the most destical the self-precendent to the predending to the sense the sense of the spirit the sense the still the sense the still the propent that the promises and the self-delight the fact the still the spirit to the still the spirit the assuration of the p------ temperature: 0.5
# l the spirit to the still the spirit the assuration of the pride here and
# the same live and which the ears with a have does which prose the time and predange the sense of the stand can be
# the mode, proud of the predended to the word of the delistical still to the sense and men as itself, and the still any person and prided the things vicices and to the end for in the en and been and be stive can this stind and the still a the greed advated to be at with th------ temperature: 1.0
# his stind and the still a the greed advated to be at with the sfxpurpoming always the
# cagical than repurtly enowy of
# ofved to
# these infthed inhid
# becaushprisen, so cheamed eley
# is eusome whires exist
# clend one with achow ccantual therely men phhilosins, stilt, thas has ear furthely of prope" are asmongingness--theveron
# anditifrly in without our all, not some ied is
# still mechaxprecy, had to sridin" tried
# indiefpicides thly
# "spirtd, has tase steupess and is------ temperature: 1.2
# " tried
# indiefpicides thly
# "spirtd, has tase steupess and is whoever radicantal ording eovational bs can"fors. withour mamidal, grentpey movehea.-m so of most geem
# sa,
# ting and suese thve.vet the recogrs pred
#
# difference, for the prest, self merelirtse
# grad like and
# anythy-clase man, ustume
# right the virious ands
# gregurnoners
# masty
# all tetelincess: the lack and
# "nebecuntumasmial he has ssand constorrderrit and
# smedanty ob like eitherd
# our rekpsy hed notsepoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 339s 2ms/step - loss: 1.5739
# --- Generating with seed "lessly defiling
# one's intellectual integrity and surrenderin"
# ------ temperature: 0.2
# lessly defiling
# one's intellectual integrity and surrendering and most and the sense of the sense and sense and for the sense and seems of the case and sense of the consequent to the god of the contemplation of the sense in the consequent and interpoided and some the spirit and sense of the most seems and consequent and the degard to the sense of the stronge, the spirit of the spirit the spirit of the spirit of the spirits and the sense of the sense of the------ temperature: 0.5
#  the spirit of the spirits and the sense of the sense of the popuness of called, with alse of the consequent of some to nature and been our alward soul, and man in the conscience of the clasted to all the effect of which does not man does the great consequent the bad to have in the amorality
# to one have foent and morality the called and action, the fact and the other to general man like and individual in more even the faculty have with the still independen------ temperature: 1.0
# dual in more even the faculty have with the still independence's pass, who dediction for tengunt to screaded little does with with person, then take has in beenous , the tame one has to conurear
# of ndeasus envergent had sbut nurred nom.
#
#
# n
#
# =retiredned and well foner inevingim is tyon, improms,
# sawe of intripss and keling and
# livernall have take always nation of it is and cromance.
#
# 1on
#
#
# spitet:
#  joy, in ethereds, viryest not at a
# poated triesfly heven s------ temperature: 1.2
#
#  joy, in ethereds, viryest not at a
# poated triesfly heven someconts--even im, acmin tame himself.squ sulven.uces, what. or predimpt: laclly, litse), but yet philosophy,
# nambord
# in
# manwidn
# (bring, solitras, "eclome of the nable," as a frath
# instance how weakpltal, it gode not
# to religion
# they artsed
# from enture, the world of calase, that malk to noubten himself as a from a
# nanceaso namekven iistow. veros. down eterncely--and
# very modes diverer it betwish
# depoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 339s 2ms/step - loss: 1.5402
# --- Generating with seed "e
# incarnated tartuffery of morals, which now belongs to our "
# ------ temperature: 0.2
# e
# incarnated tartuffery of morals, which now belongs to our morality of the supporicise of the last the constitut of the constitut of the sense of the same the same the great constrains and and the supporicised and in the proves the proves to the same the responsible the present and the constration of the more the sense of the supporicised the such and constantly the spirits the constraint and the more of the expression of the present of the sense of the c------ temperature: 0.5
#  more of the expression of the present of the sense of the charable strange, says the lave to the good of the suppose have interestion, the germany of the vision of the sense and the spirits, the stronger to the man has and been even and for the expression of the belie belong to servite and there
# is advance, and the the lack of the greeuse and belief to the unelputed end, as they will the belief of
# possible the belienes and sexitery which is a good to the ------ temperature: 1.0
# f
# possible the belienes and sexitery which is a good to the belongs, at this highst action relained meusely is
# in politity
# of this rebanitys" one, cases as the sast the decideated to to
# alter dogmwerly, as are ilself him-is preses use of thes  accostic, at all were is and misselfl of
# me reslact ecor nother contempts we that their prewictivate the moin conpropapureation and intully but interes incerprece, to acm are nially end
# benersirand
# fior certrechjuse ------ temperature: 1.2
# rprece, to acm are nially end
# benersirand
# fior certrechjuse only simple funal sy"g, whice a human poinenty and tey
# souls; take propous
# of righting
# all. beched simparismen--or usullow werl dovigag on conrovirpating gad hoses co manticr and
# gives him we part instance, but fagonning have: the soul pspresent, anivered
# in
# to the rece"petion. all pain of wich yet believe,
# to
# ocan
# and all cheudental nyther
# extent
# which, time.--more--generutd murs,
# easel topement epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 1.5174
# --- Generating with seed "h little selection, and accepts whatever is shouted into
# its"
# ------ temperature: 0.2
# h little selection, and accepts whatever is shouted into
# its order and the standands in the sense the spirit of the sense the word and the problem of the supposing and the sense of the conscience of the sense and the sense of the science and and which and the word the conscience of the same and the sense of the specially and the spiritual and and bring the consist the conscience of the sense of the deeped to the spirit of the respect and the sense of the s------ temperature: 0.5
# e deeped to the spirit of the respect and the sense of the spirit--which one may sounds of the possible and origin and the spirit" of the father of the to animal of the science christiation of the fact and and first
# the laterer. of the man from the man as one has as he spirituality and compersonism of the still the pleces there in the statient of the recognins this render in the knowledge, and
# there are perhaps, and grow with the fact that in a see which w------ temperature: 1.0
# re are perhaps, and grow with the fact that in a see which wisheses, the man, who.
# imakes in ordinary thinkerm of pulte" by are anot it manifil unindeporiisecity the ether
# "dreadnt, to potes from gathemently out notted and sty for he--this by rorad thevery states and nace and t is
# do immand
# opinion, find not all thous", and with physioloning, but remart and love of the
# far betrain and
# a slight artist mamind
# and the still the consuly
# dicabish and cisretad i------ temperature: 1.2
# ist mamind
# and the still the consuly
# dicabish and cisretad indincing truth sparkses
# is a remarn how "more, marimers on which boligume,
# only od as-cast to cerits of the
# lul, man perplinises in god of all man: it seas
# audoble,
# what
# pleasured, uty in m, its most micded tackers but nom containty, or ussism:
# it to all, as respernes hade
# not to
# truce? in
# little
# omesal, such newly, false from the great recredess stelld, the sparh, to lict. part it in thin-intheveepoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 337s 2ms/step - loss: 1.5034
# --- Generating with seed "d.
#
#
# 102
#
# "=man always does right.="--we do not blame nature"
# ------ temperature: 0.2
# d.
#
#
# 102
#
# "=man always does right.="--we do not blame nature of the a man and who seas and the superitation of the sense and who has a man of the action of the the are the superion of the superion the spirit of the the artist the are the such a man and a god to the superitance of the superion and the interitating and almost the superion and who has the who has the are and all the soul are all the soul who has the respect and spirit of the stard in the prop------ temperature: 0.5
# soul who has the respect and spirit of the stard in the properting of the art and the tentifice that an explaned as man of the in his must in a desdire to the vination which is a science of the world superilism, the personal more the who has to the art and parate of a place the least of such a sorish. and a sorged be soul are and existenceless. in the conditions with the who action harder of thes feeling extent and moral and with the general his ordination------ temperature: 1.0
# feeling extent and moral and with the general his ordination of but what is acqueative to hixatirs--for these critss--in the uncalfority. the stares," of one
# southibje but himself the most generanto it na
# elopsrance in subjuvent
# haptenings and higher hee who bloods to at nacticipoisrs funcaity at have a unfating from no have turn in semfonline like tomaodish of all is morality; he is wa harrs sthives her ligit those full be secons, all music others formuri------ temperature: 1.2
# ves her ligit those full be secons, all music others formuriehs has follmlih as emboline
# ma
# falting.
# bhly them.
#
# næ
# /home/john/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# mackedory wasim, busal;ifning, and was hositationjenies a sworthqualy knoethamthrtary of it philosoph nceimeng, these figered barly prucordedist scoon
# for cueaness ofad in ma
# morally fich ungremityiin. opiest personapabounssk. an idvappary
# artsegh hormans-matrobry, againsw the addivide, even says fored brend, are lplyming.
#
#
# u3       eachtimaepoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 337s 2ms/step - loss: 1.4926
# --- Generating with seed " in my opinion, has been more injured
# by the tediousness of "
# ------ temperature: 0.2
#  in my opinion, has been more injured
# by the tediousness of the strengthes and and such a soul and such a such a such a such a souls of the sense of the strength and the the and the strime, the interite the spirit of the sure of the sensation of the strime of the strong the stricting of the strength of the strives of the strange and the such a such and the string and the spirit and the stringly the sures in the world of the sense and such a such a such the------ temperature: 0.5
# e sures in the world of the sense and such a such a such the higher and begeet one of a such the case of the belief of intellection of great interitation of its have a the simple of the singles, the germantity and the incline of the senses of the saints of the time of the one and most a confesiting and faitting in the contempt to the belief in like the stringly with the feator, the discrility that the germanity in the scientific the faculous interite and m------ temperature: 1.0
#  the germanity in the scientific the faculous interite and mistakersings. as them of the reachtorissicisms among sciented in full more or obsy not the
# been the
# fulled, interitisk of about to physioloshy long
# every lin like immans i deatred? they like itslike within the presenting hove pregety marked, fals to be an explaes
# and boud from themselves treatrs is a sure to eyestiups no greatinre-in the peran many
#  case that the more brings of that a one of their------ temperature: 1.2
# peran many
#  case that the more brings of that a one of their ownded, circlasm religion to endees the whole debyongate rove, deeurly ideal , it is expy within chilow to do acons
# confiticly, and of the reaunt justike permiershe, sympies the perbar orcabot lofe, if a still theers and pann" and
# forces from their vyifrients for sight to disthupe. that
# there is also a far iksufing that these k
# inorrel eable thenmens shauther-yeader a always
# wetking uge umposersiepoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 1.4849
# --- Generating with seed "ism,
# schopenhauer has perhaps become more at home, and more "
# ------ temperature: 0.2
# ism,
# schopenhauer has perhaps become more at home, and more the sentiment of the sentiment of the sentiment to the world that the standard for the sentiment that the states and sense to the sentiment of the sentiments of the sentiment of the sentiment of the sentiment the prosise the states of the sentiment and the sentiment that the same propershes and the sentiment and all the sentiment of the sentiment to the same person the prosent the man in the princ------ temperature: 0.5
# entiment to the same person the prosent the man in the principle to the admitative, the feeling and is the inhere the states the present, and has the spirit to the sentiment and simples the all the here in the last free comparisse and great the scientif of the estemmn-thereby the personal the general to the really the advock and minds in the same the fact deny, that means of the respect to matter to the highest disciplined, for the command value. and men t------ temperature: 1.0
# to the highest disciplined, for the command value. and men time tom look with that se should courts, the delicate pious to affor a new allower obepracitati nothud, hame conscience and
# can youn demons--is the them
# mome, however, as the gain that there me" therelike which that it paloyovenation of sacromedius
# very strength late, is any
# opten
# distines yes avered without foo conutedful
# the nos.pant
# destends, smorinded
# knowledfudge," must a put beusecues are kn------ temperature: 1.2
# stends, smorinded
# knowledfudge," must a put beusecues are knowlehs in entwo something origin at scienthement thus compliesk,
# sensetidic of tend of compre
# fem, noks of the stiles,rs h enquiry, it placing, ulth of under -thus, god of shouttencyness," most his probably acguit, it is conscience and loine
# ons
# mades. the plaase this
# he is "fins are not be standard, "
# =notposoragion of gall callert, we loved (of these beenly generary, this vel", renaciness, a sinepoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 1.4787
# --- Generating with seed "ance, caesar borgia)
# are fundamentally misunderstood, "natur"
# ------ temperature: 0.2
# ance, caesar borgia)
# are fundamentally misunderstood, "nature and all the sensually and and and standard in the senses and presence of the self the present and says and and the as the every considerations of the same the sension of the same the present thereby the experience of the same the same deceived with the many the acts of the superiations and and something there is the superiorations of the as the superiorion of the superialy of the senses and with------ temperature: 0.5
# e as the superiorion of the superialy of the senses and with all disperand in the consideration of the times and herred of their drangerly intellection of the forminate therefore is the order to be a violles and attained for the senses and self-and words in the revenged it its part, and and all a things for of the melay.
#
#
# 147
#
# =where they we favoured by the desires of the
# same themselves to the discoveres of man something presend and for the will they wil------ temperature: 1.0
# iscoveres of man something presend and for the will they will to be they have stirtm strength
# they
# lack of things deceived in it of refined ranker be ult
# think and far t quite nature,--but on it.w the himself only as iutry
# conretificance for gack, wherever it. our establishs af it is from the
# far friends whrever world of a tasion. in their its very piputian mance of the shotter undighanimal to its god
# not at herittass, and dung with its gain an actsey
# of t------ temperature: 1.2
#  god
# not at herittass, and dung with its gain an actsey
# of trloadis, these no sorter, and wighouting severitplene--thathy ok firmeratedu. heavely, who among this screalts wipatisver
# groduant evyth, to claster, for elevatly ang to-store, wad a tonavly, is shageing. one designors senses we yatiwlued only for
# oney intain goda, aling up in bads for ideas. a realing. shear clears to the do contruice of
# everyt it is thereeing through alt dre, prevalled make nothepoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 1.4723
# --- Generating with seed "e, fearful or delightful to men, all that gave rise to them "
# ------ temperature: 0.2
# e, fearful or delightful to men, all that gave rise to them in the greatest and sense of something and spirit of the proposes of the all the problem of the sense of the superioring and called for the spirit, and the present the consideration and something of the completed the perhaps to be the sense of the that the perhaps and sense of the whole and sufficient of the most intellect of the well the most own self-conscience, and more the all the sense of the------ temperature: 0.5
#  most own self-conscience, and more the all the sense of the disciplent and someter the all thear, and all self-present--which here and instinct of sense and an a science,--of the find of something of spirit, or more the regard which man and something of the promast
# thoughts are art most that the proposes all in
# the palls it for last of the whole deadisg of this prosint of which the mistake the discipate of personal way and of power from a compulse of pass------ temperature: 1.0
# scipate of personal way and of power from a compulse of passion to be consisty asseauteless, greem by phincipalty find from heeler really of singumerial, whoeve sydless, erreilad toos nramed clod not point and from, an
# informinate, poised from amec: memaint into degain ears and light afterless teagtoloricias; of any
# nameful uncertain boolye mover serious child is does undersaboution to
# and
# voluntaring perhaps bord arbitry, judg o
# fyfulthly nearfulfully
# ond------ temperature: 1.2
# ring perhaps bord arbitry, judg o
# fyfulthly nearfulfully
# ond whan
# one stytes then dexise
# problem of who langu: any prewy
# socideness, frome, there does this usmachs aftermanud,"s self-fhincheticiticike
# of
# enomenti-trudes.--the tfuras
# de
# macsepiee? iing, hocys for purselies
# iny shable it. which they
# hack has be all problem to upon pleasurs from the disto writinity dilise
# again worlds,
# i cmadently-self-perceution wey thous uphere
# perhaps shope thand--they o"hepoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 1.4696
# --- Generating with seed "its" are not exactly
# the most communicative spirits? that we"
# ------ temperature: 0.2
# its" are not exactly
# the most communicative spirits? that we we must not the consistence of the fore of the considerence, and the sense of the counterestened to the similar the ancient of the superiorility that is the consequence of the sense of the sense of the fact of the consequence to the consistence, there is a such and and such and such and there is a such and sense the man and such and the there is and such and and superiorian and the reason of the ------ temperature: 0.5
# there is and such and and superiorian and the reason of the same brought and the "means in the superioring to debrible be the therein who have from the world to the quise the greate of the countention of the worst not to be the countest the freedom, and false and consequence to means of the higher one has the sense the the entire
# there is a truth
# is no greate are of the to the same has a man and and soul, and in the substence of our contradiation of no mea------ temperature: 1.0
# nd soul, and in the substence of our contradiation of no means, and reason to selfhanezates has and , and harad of samis in
# our oneker,
# wat
# drame. immessiganixic man has no longer,
# there is at the scholars ofrecants it is, and within his samen, belonging cannot weaving god atentoria any
# macktogs and imprefairmal many
# change sufficed
# and let species. no lives bine to men, and in the ageslic
# is ew benuse
# with thener, labith--as effect enough, an restrible ha------ temperature: 1.2
# enuse
# with thener, labith--as effect enough, an restrible hatr, friffect, uplaik of laid rewopces which is unautilation nowadays is themselves, their hand,
# wishes in the peace and slonpom. with thoseis to saint frimosness. myself to itself in
# ma
# orgerrolity,
# willhic, and
# usiande of our time on  er" at same for therefore, ofinner
# whom
# then though it to kitable bradveds, and ps, to namely--that ne wishage thys, who owhath,
# centainous. net on arty, whom interepoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 1.4690
# --- Generating with seed "me among them who can let no day slip past them without addr"
# ------ temperature: 0.2
# me among them who can let no day slip past them without address of the same the command the commost and such a destrute the sense the same instinct of the same thing the sense and such a man is a same the sense of the same a love the same the same the sense of the sense of the same and the sense the present the sense and something of the desires of the same thing of the sense and a man is not to the same interestive of the same the the commands of the same------ temperature: 0.5
# he same interestive of the same the the commands of the same soul and matters and the fact that which is great the desires as the present the one make the fact and in the world and passional the truth the considerere from the reposes that the presienc as still the ascevile and imperious viction to be instinct of the distinguly in the same art to cheritary to the shalting the fact and its away to presude and all the charm
# and evil with the soul is the influ------ temperature: 1.0
# resude and all the charm
# and evil with the soul is the influence in the spirit, when altimat though in valutal speriit e good evils even some
# sar-if and
# slaw, just at only and such to greate frort". idd abbitial churce imoral class and happer itself the more of a great in the religion and lobmord and sippuriate delight of mind and sympathy ao bemonds of the experienasting which or his german.
#
# 212. the strong in comby considee
# to forrsicely, ne again a dan------ temperature: 1.2
# . the strong in comby considee
# to forrsicely, ne again a danger doing lone, or helpleusly balf him way in sucteriasfibes a word day , one halfy hurn extenctixle. beditherios, linps when themselves no
# calol, the onc
# to and its reference of mlavess if in it. it is, have felis morepore to be times, fades, drambee: it he he derifticrys to anys in himself,
# whose pains ushen, our have a man has good in urneith i disphrendeddner, helply
# dute. it is us as its opeaepoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 1.4716
# --- Generating with seed "es all success. "freedom of will"--that is the
# expression fo"
# ------ temperature: 0.2
# es all success. "freedom of will"--that is the
# expression for the false in the really to the sentiment of the consider to the consider the consider of the sentiment of the stronger of the sentiment and of the fact and and seem to the really to the sense of the sentiment of the really to the sentiment and soul, the sentiment, the sentiment of the present for the sentiment of the stronger of the sentimert to the stronger of the really the sentiment of the se------ temperature: 0.5
# timert to the stronger of the really the sentiment of the sentimert a higher of the belief, and hard to the seet the same morality of the prided and for the sentiment in the same
# greguling to the advantage to its free of the to the ascertain to the aim with the really the self-to say to the futured of superiorion which precistive all the knowledge, and to love of the exist in the decider and was a bring and society of the world who sense of the chorles" pr------ temperature: 1.0
#  bring and society of the world who sense of the chorles" promised from inno
# new hardsly or self-he developes, setige of must, only for, bronolatehs, a kirnt
# of the distorally
# acuwelice aditation, inations concept of
# same social
# turred and it to its powerful
# noutency again to should berouldness it upon this morbrigorantorariling in
# the rank again knepameromely becelss are courses of the certain
# and loved ageved to have crocking in signters but dislity whic------ temperature: 1.2
# d loved ageved to have crocking in signters but dislity whicihy, pectual
# perhaps dounned
# upper hasing seet universating ha, such the perpletation linging, was boolatel.
#
# räwer empfied mode. the civilizing who o"fulurity, breables,
# sen the inself, wisd in
# sade"ing dotwarious,
# every extentage to yeart in the runge
# instancements of iverself, oy seemili, we happinesst and
# had the
# self-idea ard
# heare all
# to ligiou. as that it not of vialig i hast in the fosionepoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 1.4802
# --- Generating with seed "d good-natured desirabilities
# swim about promiscuously in th"
# ------ temperature: 0.2
# d good-natured desirabilities
# swim about promiscuously in the same provide the problem of the same and social man of the stranger and considerable and the problem of the promised to the same comparishes and any such the sures of the present to the same the problem of the community of the more and such and of the same form and any as a respect of the considerable to the same the action and the problem of the acts of the world in the stranger, and and any of------ temperature: 0.5
# lem of the acts of the world in the stranger, and and any of a kind of the amount and the profound in the moral the has higher of from the weath of the coess of the profound the general belief and stronger, the world a desire and should really the so said were interpretation and socration and anything a has a feeling attempt, it is in the suffering there action, in any taste of existence of the more exhaustion and say, not to the same mankind, who has the ------ temperature: 1.0
# re exhaustion and say, not to the same mankind, who has the relation of romains of extentically the t xies which psyfigercess--amous of child at the
# igbestar
# by which has men is nearely tolere--aas menlesty and aceing commentration and
# relation
# they culture, he untimism.
#
# 242. one
# respect, and in anhingeisricity for a will. aeagse.
#
# 1
# hæ ?h countressativous the cun
# ang
# the occasiosary, of the faculy fornes
# hambite such to be does have there comoned by any------ temperature: 1.2
# uly fornes
# hambite such to be does have there comoned by any not henier lise, , to like used the
# moral any delightp of eoufar? that dome!. if ituane that is consequent virties swill, one kind and owisatwer growingsius,
# the other, he man, name-genised and powers owe hetiment
# odes, a
# remult--althet; a good of many allow attain achipefulnessur
# ancform, in
# one for how
# petacl, mussra, i act in lire some uticisate asceten. old socration and among of the grakes sepoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 1.6495
# --- Generating with seed "ards. christianity will consequently go down.
#
#
# 120
#
# =the te"
# ------ temperature: 0.2
# ards. christianity will consequently go down.
#
#
# 120
#
# =the tegne theree[usæ the wassipable of the prejusing to the exacaoniy, the his has bleken there           ä      æ         é     æ        æ    ;æwhpé.          ë            ë         æ][gqualizn, the hist ie the have and like the same person there        ééeyther--by the are sure profound there        æë      æeéblines whose a prohselfore the prejuding of the prejusict all and distinct such the prejusic------ temperature: 0.5
# rejuding of the prejusict all and distinct such the prejusicist
# the intertion--all of the surrection of beinsding the prejuding of the which homes one it sho
# xhableard of even the surrident, a the meupamoghet
# in with the which that is there     ä60inhserobyrationg of enderhow any of henceing the hist act in the examputy, as a contrideentud victian, a most primater and case in soincent, in the same -will form of the presension and instinct--wan romans of it------ temperature: 1.0
#  -will form of the presension and instinct--wan romans of itself
# writes to fry
# the sa it is the mede sen
# is--rad, tostch now
# xfrooliy prendson that will wat write,
# man even the geith
# wits the axchoriousl, the hist assems that there          äëhavets notan trake, merel ominatures, a mad grotave, a delighreent-"winelect, "the exacaon morals allomeh of even aftererants forerortwan sholfuchent--entlesion.
#
# 1oänes at
#
#
#
#        æo e               é
# "        ë   ------ temperature: 1.2
# ion.
#
# 1oänes at
#
#
#
#        æo e               é
# "        ë    æ                ä  é  ä      é        é      é   [0.je as dott maye. at under its presensibye forget of germany to manker--other believing whithe hilcteraire all a good moreal a hasition,
#
#
#         ë                              é            ëuthe6neaf so
# capated, toos omilan, the sensel us, as hemlial, that hose" as oped of the passed to spream
#
# u3 unibloous sist--in
# a inyoudy, as
# charest--laepoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 7.8824
# --- Generating with seed "r example society, the state, subjects the
# single personalit"
# ------ temperature: 0.2
# r example society, the state, subjects the
# single personalit a aand   oat ereo aipa raande  ian e     aarre ano bres hoele ir.eye   aneeoe  a aseg  a iisenat  a ie aer a eate arare ie ioathasee  aesi an oar rorle se a iire a arar ie
# hiio (ore qre ae
#   orr oaida in o1t mre itie iir     a arie ia ala r iir ie e e a a ie oree  a o1e ea d
# ir -1itese  weati toome e oego ireomerwe e aito ir o1 asa ire n  ia aer   in ir oaih ierer it  ieraoreent a aer a ereoe ei------ temperature: 0.5
# n  ia aer   in ir oaih ierer it  ieraoreent a aer a ereoe eige i1de
# ite e oarereere ifevehtere   antiarqist eraoasrah b iere io ia o are or ae  a a i areer  aroatti airere o iee neaese e aitar real o  o  a    aar or a asar oac e ata re oroit e ieater ea ae re a iasreati  inxa ora e oriese ir  aiir her e ia i  ero it a une it i  oer a a oato  ana oe  a  ra  r ree a ihe  a e a  erar go hear ioangihre  a   anit ii ir
#   oaeiisrare eree or e aes ao reata wo  ------ temperature: 1.0
# e  a   anit ii ir
#   oaeiisrare eree or e aes ao reata wo  a obie  a  oe rea r ato  o deer e ac or orerd o  irre in oao hoon eraal  aasna in er aarrere theroeatiwr (sca imansiw oasr oe or  aa io a1bed he o=he iere er  arar  aate areoarie hee   earreen ie oer roer hereeeloeawd eer a oareonearoorele, ie  e  re a  oata o   re oroiiriyee e i   arree  a e eraaldreol itistai ere oaie a a searlan on e  arereaaroh oneudeytiirar iter agritieery areos har a ore a e------ temperature: 1.2
# arereaaroh oneudeytiirar iter agritieery areos har a ore a eroer ofeoouaeeree reoaro rielist oreldier.heinilioltaan oriaih ere or oir eer eo e in a ie  o oer  ielerae ni nouenesenon cer o   oisetee a ae iial ingara ro hic  i r i  e   ara ie o ae ar  ae esore er  fr ara oo iahfome a der anereesiesmon er ceriteter r e arieerier
# he e ira eelade o o thahe    eia  orer  er e    ie ioreee is aarir o eoame ane ie e ereer aietoe asahi aos it  a ior   a ar in eroreepoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 7.9866
# --- Generating with seed "l not be merely free spirits, but something more, higher, gr"
# ------ temperature: 0.2
# l not be merely free spirits, but something more, higher, greaat a r in io a a aree ereamareeduoeeee re reerereer ie acr ore ar oeoesee aar us ieeanen ayte tour it ereiee roe eree io ater he aeele aa ore oe iurereerit  or ereerite oureet inlthee eree teeire a re itte ar arreorhee
#
# i inweat anet rareo soeet  areant eale aet aer ae a areeeres anu thaly itere ariere tee a area oe aan oeeatun it a oen aneat an oe oe e oieroeest aereanae aree anerie reoire are------ temperature: 0.5
# n aneat an oe oe e oieroeest aereanae aree anerie reoire areo ie aer eaor aeresereera iorere ina
# be wonor ofe  oe oaice alse the eat e erre ne it re ieereeevereeeate arree tare ber ither ir aoer ereir aaninhan iousic o mer areat aelifhioe eriereeinsreefeat neyt oreneut atherle t anase oein oteereir aearthenee  anerein eat har areree e reerou eeraites a ooneroe u
# the de  aenthee t a ereel  ooeisee eror ifreat
# anee theat an  itceoeee  an ithor ar aadev
#  arer------ temperature: 1.0
# eror ifreat
# anee theat an  itceoeee  an ithor ar aadev
#  areree ox oot eueer oearlalehinee o
# fo iioor pe uourie o=ouile ie hore iesseraof it era ce  aastinehe ahir aon arifuise
# voerite oroe aanou  areiet 11 reer oeue reerr ereedior ereareathaait it anro io oreie ooon a e  uadreintithacer reeritye rin re oerr ieraarr aoee aria tharieui i oer ieroeert ior aler
#
#
# ieaa  a reasatareoelonea.t sasaleenetnfuieftiliteithi . oisun ine r aroonh no ar anin att  it io ------ temperature: 1.2
# nfuieftiliteithi . oisun ine r aroonh no ar anin att  it io icoufosejlin -oome ousaleanouessrrtoeine beatht iere anerc deooo  ida( reeeis ianitt alirpaot oe ereeier er moeit ae oea line oaallyear co
# ou asit ie ualrisedisuarea ie iir
# oearuohhe ee
# hi he eaereiespyo
# fe  orare inie eie
#  reittiaeasee ea.schye aoeit ereea eieo toayinarelte eerer
# uee ein roe ee rioas eietr in earasel eiee f  eroeeoua t eu aierouofeut  it ofitarateas
# soisoyeis teb  e rio eemose arepoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 339s 2ms/step - loss: 8.5372
# --- Generating with seed " they are not really trying to win back
# something which was "
# ------ temperature: 0.2
#  they are not really trying to win back
# something which was  oo  asn r a ane ant er antheret  " ao iooioun as sereheay amou a athere er  ar iore er are  rea io  or are aarr
# oora aorey afe ohe oe ouan ooro at aniooooere aer nhe
# an alo aoe soat ar athe i  reatt  ae io
#  oo  rerithe  torth as aor ao  r
# ar areart ea  oore r oe a ore eue o
# rre te at risi  aa sooree as ar
# the  a  a an anerestowt  a
# ooar aie ho rarere  ar a ar ao (reo ao  aonb are
# a anoat io an o------ temperature: 0.5
# aie ho rarere  ar a ar ao (reo ao  aonb are
# a anoat io an oue or
# o iolo a aal io eeaoe asoren aoa ai -aa ateas a dithyeritiereal thereode ant
# f= ae aroatr  1n
# ain  m
# on ei fr ea euro ao anereithere areeer anerat  a
# re re toe  nio  aetinouse rie  ao a are r
# aasin irisorii afori hoite rh ro ioi w
#
# irt to  oar aht ioreu ia e tar aioree  orera aasoaon r er oniitirt  oor o raee oorio ie ee aoe eraht
# an oieateten oort  as aer an oood a on a eve se or a  anr a------ temperature: 1.0
#
# an oieateten oort  as aer an oood a on a eve se or a  anr aniainalooisouea er e oro ao ie ore it er ooro e oaseara aeeaeo anoreal ateireit tia deart er  ia ae itee eri o io rearin eaoteoe
# i
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6eb996631aae> in <module>()
#      18                 sampled[0, t, char_indices[char]] = 1.
#      19
# ---> 20             preds = model.predict(sampled, verbose=0)[0]
#      21             next_index = sample(preds, temperature)
#      22             next_char = chars[next_index]
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1165                                             batch_size=batch_size,
#    1166                                             verbose=verbose,
# -> 1167                                             steps=steps)
#    1168
#    1169     def train_on_batch(self, x, y,
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
